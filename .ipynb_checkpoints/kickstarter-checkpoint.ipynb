# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import ast
# import nltk
import glob
import tensorflow as tf

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, make_pipeline

# from nltk.sentiment import SentimentIntensityAnalyzer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.metrics import Precision, Recall, Accuracy, AUC
 

plt.style.use('ggplot')
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 100)

# %%
# get data file names
filenames = glob.glob('data' + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
df = pd.concat(dfs, ignore_index=True)
#link = 's3a://helen.assignment/master.csv'

# %%
df.head()
# Out:
#    backers_count  \
# 0              5
# 1             19
# 2              5
# 3             23
# 4              0
#
#                                                                                                  blurb  \
# 0  A Free to Win Online Mobile Strategy Game to end the corruption of the rich players always winni...
# 1                   Lizard is a dark comedy and modern western, that takes place in the Mojave Desert.
# 2  My friend and I are making an app that has never been made before. Making a football turn based ...
# 3                                                  More than a bike trip, a state of mind. And a book.
# 4  This is the birth of a revolutionary artist...Revery! A burst out into the world with GAME CHANG...
#
#                                                                                               category  \
# 0  {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 1  {"id":11,"name":"Film & Video","slug":"film & video","position":7,"color":16734574,"urls":{"web"...
# 2  {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 3  {"id":48,"name":"Nonfiction","slug":"publishing/nonfiction","position":9,"parent_id":18,"parent_...
# 4  {"id":39,"name":"Hip-Hop","slug":"music/hip-hop","position":8,"parent_id":14,"parent_name":"Musi...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        83      CA                   Canada  1506125024
# 1                      2358      US        the United States  1561667598
# 2                       172      US        the United States  1453500203
# 3                       501      US        the United States  1345516420
# 4                         0      US        the United States  1510267562
#
#                                                                                                creator  \
# 0  {"id":1178629187,"name":"Adam Tompkins","is_registered":null,"chosen_currency":null,"is_superbac...
# 1  {"id":1624125450,"name":"Darrin Williams","slug":"lizardshortfilm","is_registered":null,"chosen_...
# 2  {"id":1843687675,"name":"Mike Teorsky","is_registered":null,"chosen_currency":null,"is_superback...
# 3  {"id":376746530,"name":"John Farley","is_registered":null,"chosen_currency":null,"is_superbacker...
# 4  {"id":1163714172,"name":"Revery (deleted)","is_registered":null,"chosen_currency":null,"is_super...
#
#   currency currency_symbol  currency_trailing_code current_currency  \
# 0      CAD               $                    True              USD
# 1      USD               $                    True              USD
# 2      USD               $                    True              USD
# 3      USD               $                    True              USD
# 4      USD               $                    True              USD
#
#      deadline  disable_communication friends  fx_rate     goal          id  \
# 0  1507560063                  False     NaN  0.70837   1000.0   751419376
# 1  1569109188                  False     NaN  1.00000   1100.0   289952460
# 2  1458681077                  False     NaN  1.00000  25000.0    37585826
# 3  1348540386                  False     NaN  1.00000    500.0  1727301949
# 4  1512960191                  False     NaN  1.00000   2500.0   144196412
#
#   is_backing  is_starrable is_starred  launched_at  \
# 0        NaN         False        NaN   1506350463
# 1        NaN         False        NaN   1563925188
# 2        NaN         False        NaN   1453500677
# 3        NaN         False        NaN   1347676386
# 4        NaN         False        NaN   1510281791
#
#                                                                                               location  \
# 0  {"id":22664159,"name":"Mississauga","slug":"mississauga-ca","short_name":"Mississauga, Canada","...
# 1  {"id":2452741,"name":"Mojave","slug":"mojave-ca","short_name":"Mojave, CA","displayable_name":"M...
# 2  {"id":2473224,"name":"Pittsburgh","slug":"pittsburgh-pa","short_name":"Pittsburgh, PA","displaya...
# 3  {"id":12589335,"name":"Brooklyn","slug":"brooklyn-ny","short_name":"Brooklyn, NY","displayable_n...
# 4  {"id":2374418,"name":"Canoga Park","slug":"canoga-park-los-angeles-ca","short_name":"Canoga Park...
#
#                                                          name permissions  \
# 0  Iron Age Kingdoms - First Free To Win Mobile Strategy Game         NaN
# 1                                       "Lizard" a short film         NaN
# 2                               Total Franchise Football 2016         NaN
# 3     The Trans-American Psychogeographic Literary Cycle Tour         NaN
# 4                      The Golden Ticket to the Wonka Factory         NaN
#
#                                                                                                  photo  \
# 0  {"key":"assets/018/444/378/81e59ccab10259506aab6ee340d25b73_original.png","full":"https://ksr-ug...
# 1  {"key":"assets/025/890/832/ff7ffe91d4b15641a58cb7787182e070_original.jpg","full":"https://ksr-ug...
# 2  {"key":"assets/012/361/145/208a4baab227d49c5d23f46a8361cd9c_original.jpg","full":"https://ksr-ug...
# 3  {"key":"assets/011/414/575/8e408be031b76a8b9f7d9915c6b0ef62_original.jpg","full":"https://ksr-ug...
# 4  {"key":"assets/019/151/238/a73360e8eb4dc7140eb13f638ea8f11d_original.JPG","full":"https://ksr-ug...
#
#    pledged  \
# 0    105.0
# 1   2358.0
# 2    172.0
# 3    501.0
# 4      0.0
#
#                                                                                                profile  \
# 0  {"id":3151330,"project_id":3151330,"state":"inactive","state_changed_at":1506125024,"name":null,...
# 1  {"id":3762384,"project_id":3762384,"state":"active","state_changed_at":1569117788,"name":""Lizar...
# 2  {"id":2335556,"project_id":2335556,"state":"inactive","state_changed_at":1453500203,"name":null,...
# 3  {"id":311225,"project_id":311225,"state":"inactive","state_changed_at":1425915817,"name":null,"b...
# 4  {"id":3214412,"project_id":3214412,"state":"inactive","state_changed_at":1510267562,"name":null,...
#
#                                                  slug  \
# 0  iron-age-kingdoms-first-free-to-win-mobile-strateg
# 1                                 lizard-a-short-film
# 2                       total-franchise-football-2016
# 3  the-trans-american-psychogeographic-literary-cycle
# 4              the-golden-ticket-to-the-wonka-factory
#
#                                                               source_url  \
# 0   https://www.kickstarter.com/discover/categories/games/mobile%20games
# 1       https://www.kickstarter.com/discover/categories/film%20&%20video
# 2   https://www.kickstarter.com/discover/categories/games/mobile%20games
# 3  https://www.kickstarter.com/discover/categories/publishing/nonfiction
# 4          https://www.kickstarter.com/discover/categories/music/hip-hop
#
#    spotlight  staff_pick       state  state_changed_at  static_usd_rate  \
# 0      False       False      failed        1507560063         0.810764
# 1       True       False  successful        1569109188         1.000000
# 2      False       False      failed        1458681110         1.000000
# 3       True       False  successful        1348540386         1.000000
# 4      False       False      failed        1512960191         1.000000
#
#                                                                                                   urls  \
# 0  {"web":{"project":"https://www.kickstarter.com/projects/1178629187/iron-age-kingdoms-first-free-...
# 1  {"web":{"project":"https://www.kickstarter.com/projects/lizardshortfilm/lizard-a-short-film?ref=...
# 2  {"web":{"project":"https://www.kickstarter.com/projects/1843687675/total-franchise-football-2016...
# 3  {"web":{"project":"https://www.kickstarter.com/projects/376746530/the-trans-american-psychogeogr...
# 4  {"web":{"project":"https://www.kickstarter.com/projects/1163714172/the-golden-ticket-to-the-wonk...
#
#    usd_pledged  usd_type
# 0    85.130189  domestic
# 1  2358.000000  domestic
# 2   172.000000  domestic
# 3   501.000000  domestic
# 4     0.000000  domestic

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409250 entries, 0 to 409249
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   backers_count             409250 non-null  int64
#  1   blurb                     409236 non-null  object
#  2   category                  409250 non-null  object
#  3   converted_pledged_amount  409250 non-null  int64
#  4   country                   409250 non-null  object
#  5   country_displayable_name  409250 non-null  object
#  6   created_at                409250 non-null  int64
#  7   creator                   409250 non-null  object
#  8   currency                  409250 non-null  object
#  9   currency_symbol           409250 non-null  object
#  10  currency_trailing_code    409250 non-null  bool
#  11  current_currency          409250 non-null  object
#  12  deadline                  409250 non-null  int64
#  13  disable_communication     409250 non-null  bool
#  14  friends                   312 non-null     object
#  15  fx_rate                   409250 non-null  float64
#  16  goal                      409250 non-null  float64
#  17  id                        409250 non-null  int64
#  18  is_backing                312 non-null     object
#  19  is_starrable              409250 non-null  bool
#  20  is_starred                312 non-null     object
#  21  launched_at               409250 non-null  int64
#  22  location                  408872 non-null  object
#  23  name                      409250 non-null  object
#  24  permissions               312 non-null     object
#  25  photo                     409250 non-null  object
#  26  pledged                   409250 non-null  float64
#  27  profile                   409250 non-null  object
#  28  slug                      409250 non-null  object
#  29  source_url                409250 non-null  object
#  30  spotlight                 409250 non-null  bool
#  31  staff_pick                409250 non-null  bool
#  32  state                     409250 non-null  object
#  33  state_changed_at          409250 non-null  int64
#  34  static_usd_rate           409250 non-null  float64
#  35  urls                      409250 non-null  object
#  36  usd_pledged               409250 non-null  float64
#  37  usd_type                  408890 non-null  object
# dtypes: bool(5), float64(5), int64(7), object(21)
# memory usage: 105.0+ MB
# (409250, 38)

# %% [markdown]
# ## Data Cleaning

# %%
cols_to_convert = ['created_at', 'state_changed_at', 'deadline', 'launched_at']
for c in cols_to_convert:
    df[c] = pd.to_datetime(df[c], origin='unix', unit='s')

# %%
print(df['friends'].unique())
print(df['is_backing'].unique())
print(df['is_starred'].unique())
print(df['permissions'].unique())
print(df['currency_symbol'].unique())
print(df['currency_trailing_code'].unique())
print(df['current_currency'].unique())
print(df['currency'].unique())
print(df['usd_type'].unique())
# Out:
# [nan '[]']
# [nan False]
# [nan False True]
# [nan '[]']
# ['$' '€' '¥' '£' 'kr' 'Fr ']
# [ True False]
# ['USD' 'EUR' 'CAD']
# ['CAD' 'USD' 'EUR' 'JPY' 'AUD' 'GBP' 'SGD' 'DKK' 'NOK' 'MXN' 'HKD' 'SEK'
#  'NZD' 'CHF']
# ['domestic' nan]

# %%
df[df['id'] == 1875733470]
# Out:
#         backers_count  \
# 27934             128
# 162077            128
# 324259            128
# 394741            128
#
#                                                                                                       blurb  \
# 27934   Help us take our hand-dyed farm yarns on the road in a custom trailer complete with a dye statio...
# 162077  Help us take our hand-dyed farm yarns on the road in a custom trailer complete with a dye statio...
# 324259  Help us take our hand-dyed farm yarns on the road in a custom trailer complete with a dye statio...
# 394741  Help us take our hand-dyed farm yarns on the road in a custom trailer complete with a dye statio...
#
#                                                                                                    category  \
# 27934   {"id":348,"name":"Knitting","slug":"crafts/knitting","position":6,"parent_id":26,"parent_name":"...
# 162077  {"id":348,"name":"Knitting","slug":"crafts/knitting","position":6,"parent_id":26,"parent_name":"...
# 324259  {"id":348,"name":"Knitting","slug":"crafts/knitting","position":6,"parent_id":26,"parent_name":"...
# 394741  {"id":348,"name":"Knitting","slug":"crafts/knitting","position":6,"parent_id":26,"parent_name":"...
#
#         converted_pledged_amount country country_displayable_name  \
# 27934                       8995      US        the United States
# 162077                      8995      US        the United States
# 324259                      8995      US        the United States
# 394741                      8995      US        the United States
#
#                 created_at  \
# 27934  2016-06-02 23:45:41
# 162077 2016-06-02 23:45:41
# 324259 2016-06-02 23:45:41
# 394741 2016-06-02 23:45:41
#
#                                                                                                     creator  \
# 27934   {"id":2004942297,"name":"Kelly L. Corbett","slug":"romneyridge","is_registered":null,"chosen_cur...
# 162077  {"id":2004942297,"name":"Kelly L. Corbett","slug":"romneyridge","is_registered":null,"chosen_cur...
# 324259  {"id":2004942297,"name":"Kelly L. Corbett","slug":"romneyridge","is_registered":null,"chosen_cur...
# 394741  {"id":2004942297,"name":"Kelly L. Corbett","slug":"romneyridge","is_registered":null,"chosen_cur...
#
#        currency currency_symbol  currency_trailing_code current_currency  \
# 27934       USD               $                    True              USD
# 162077      USD               $                    True              USD
# 324259      USD               $                    True              USD
# 394741      USD               $                    True              USD
#
#                   deadline  disable_communication friends  fx_rate    goal  \
# 27934  2016-07-13 16:32:43                  False     NaN      1.0  8000.0
# 162077 2016-07-13 16:32:43                  False     NaN      1.0  8000.0
# 324259 2016-07-13 16:32:43                  False     NaN      1.0  8000.0
# 394741 2016-07-13 16:32:43                  False     NaN      1.0  8000.0
#
#                 id is_backing  is_starrable is_starred         launched_at  \
# 27934   1875733470        NaN         False        NaN 2016-06-13 16:32:43
# 162077  1875733470        NaN         False        NaN 2016-06-13 16:32:43
# 324259  1875733470        NaN         False        NaN 2016-06-13 16:32:43
# 394741  1875733470        NaN         False        NaN 2016-06-13 16:32:43
#
#                                                                                                    location  \
# 27934   {"id":2523917,"name":"Woolwich","slug":"woolwich-me","short_name":"Woolwich, ME","displayable_na...
# 162077  {"id":2523917,"name":"Woolwich","slug":"woolwich-me","short_name":"Woolwich, ME","displayable_na...
# 324259  {"id":2523917,"name":"Woolwich","slug":"woolwich-me","short_name":"Woolwich, ME","displayable_na...
# 394741  {"id":2523917,"name":"Woolwich","slug":"woolwich-me","short_name":"Woolwich, ME","displayable_na...
#
#                                           name permissions  \
# 27934   Romney Ridge Yarns & Wool Pop-Up Shop!         NaN
# 162077  Romney Ridge Yarns & Wool Pop-Up Shop!         NaN
# 324259  Romney Ridge Yarns & Wool Pop-Up Shop!         NaN
# 394741  Romney Ridge Yarns & Wool Pop-Up Shop!         NaN
#
#                                                                                                       photo  \
# 27934   {"key":"assets/012/618/886/97cc3d7948615efb7b5c5941c00d0aff_original.JPG","full":"https://ksr-ug...
# 162077  {"key":"assets/012/618/886/97cc3d7948615efb7b5c5941c00d0aff_original.JPG","full":"https://ksr-ug...
# 324259  {"key":"assets/012/618/886/97cc3d7948615efb7b5c5941c00d0aff_original.JPG","full":"https://ksr-ug...
# 394741  {"key":"assets/012/618/886/97cc3d7948615efb7b5c5941c00d0aff_original.JPG","full":"https://ksr-ug...
#
#         pledged  \
# 27934    8995.0
# 162077   8995.0
# 324259   8995.0
# 394741   8995.0
#
#                                                                                                     profile  \
# 27934   {"id":2543599,"project_id":2543599,"state":"active","state_changed_at":1468592118,"name":"Romney...
# 162077  {"id":2543599,"project_id":2543599,"state":"active","state_changed_at":1468592118,"name":"Romney...
# 324259  {"id":2543599,"project_id":2543599,"state":"active","state_changed_at":1468592118,"name":"Romney...
# 394741  {"id":2543599,"project_id":2543599,"state":"active","state_changed_at":1468592118,"name":"Romney...
#
#                                            slug  \
# 27934   romney-ridge-yarns-and-wool-pop-up-shop
# 162077  romney-ridge-yarns-and-wool-pop-up-shop
# 324259  romney-ridge-yarns-and-wool-pop-up-shop
# 394741  romney-ridge-yarns-and-wool-pop-up-shop
#
#                                                              source_url  \
# 27934   https://www.kickstarter.com/discover/categories/crafts/knitting
# 162077  https://www.kickstarter.com/discover/categories/crafts/knitting
# 324259           https://www.kickstarter.com/discover/categories/crafts
# 394741           https://www.kickstarter.com/discover/categories/crafts
#
#         spotlight  staff_pick       state    state_changed_at  \
# 27934        True       False  successful 2016-07-13 16:32:43
# 162077       True       False  successful 2016-07-13 16:32:43
# 324259       True       False  successful 2016-07-13 16:32:43
# 394741       True       False  successful 2016-07-13 16:32:43
#
#         static_usd_rate  \
# 27934               1.0
# 162077              1.0
# 324259              1.0
# 394741              1.0
#
#                                                                                                        urls  \
# 27934   {"web":{"project":"https://www.kickstarter.com/projects/romneyridge/romney-ridge-yarns-and-wool-...
# 162077  {"web":{"project":"https://www.kickstarter.com/projects/romneyridge/romney-ridge-yarns-and-wool-...
# 324259  {"web":{"project":"https://www.kickstarter.com/projects/romneyridge/romney-ridge-yarns-and-wool-...
# 394741  {"web":{"project":"https://www.kickstarter.com/projects/romneyridge/romney-ridge-yarns-and-wool-...
#
#         usd_pledged  usd_type
# 27934        8995.0  domestic
# 162077       8995.0  domestic
# 324259       8995.0  domestic
# 394741       8995.0  domestic

# %%
df['id'].value_counts()
# Out:
# 2048996672    4
# 373804148     4
# 1460555984    4
# 949167493     4
# 865816103     4
#              ..
# 60795511      2
# 42880109      2
# 1890468972    2
# 405175403     2
# 1329596417    2
# Name: id, Length: 180753, dtype: int64

# %%
#remove all duplicate rows
df.drop_duplicates(subset='id', keep='first', inplace=True)
df.shape
# Out:
# (180753, 38)

# %%
df[df['id'] == 1103759530]
# Out:
#         backers_count  \
# 122464            100
#
#                                                                                                       blurb  \
# 122464  New folk music & song show by Derby trio Moirai. A 100 year old tale of fake news, family values...
#
#                                                                                                    category  \
# 122464  {"id":37,"name":"Country & Folk","slug":"music/country & folk","position":5,"parent_id":14,"pare...
#
#         converted_pledged_amount country country_displayable_name  \
# 122464                      3852      GB       the United Kingdom
#
#                 created_at  \
# 122464 2019-08-28 09:55:39
#
#                                                                                                     creator  \
# 122464  {"id":612927420,"name":"Moirai","slug":"alicewheeldonstory","is_registered":null,"chosen_currenc...
#
#        currency currency_symbol  currency_trailing_code current_currency  \
# 122464      GBP               £                   False              USD
#
#                   deadline  disable_communication friends  fx_rate    goal  \
# 122464 2019-10-16 17:00:11                  False     NaN  1.24678  2500.0
#
#                 id is_backing  is_starrable is_starred         launched_at  \
# 122464  1103759530        NaN         False        NaN 2019-09-16 17:00:11
#
#                                                                                                    location  \
# 122464  {"id":18114,"name":"Derby","slug":"derby-gb","short_name":"Derby, UK","displayable_name":"Derby,...
#
#                                                                name  \
# 122464  Framed: The Alice Wheeldon Story - help us spread the word!
#
#        permissions  \
# 122464         NaN
#
#                                                                                                       photo  \
# 122464  {"key":"assets/026/358/508/1b804b34c2c5dbe3174260f0c019bbb1_original.png","full":"https://ksr-ug...
#
#         pledged  \
# 122464   3021.0
#
#                                                                                                     profile  \
# 122464  {"id":3802244,"project_id":3802244,"state":"inactive","state_changed_at":1566986139,"name":null,...
#
#                                                            slug  \
# 122464  framed-the-alice-wheeldon-story-help-us-spread-the-word
#
#                                                                       source_url  \
# 122464  https://www.kickstarter.com/discover/categories/music/country%20&%20folk
#
#         spotlight  staff_pick       state    state_changed_at  \
# 122464       True       False  successful 2019-10-16 17:00:11
#
#         static_usd_rate  \
# 122464         1.250602
#
#                                                                                                        urls  \
# 122464  {"web":{"project":"https://www.kickstarter.com/projects/alicewheeldonstory/framed-the-alice-whee...
#
#         usd_pledged  usd_type
# 122464  3778.068189  domestic

# %%
df['state'].value_counts()
# Out:
# successful    97906
# failed        71720
# canceled       8593
# live           2534
# Name: state, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))

x = df['state'].value_counts()
ax.bar(x.index, height=x.values, width=0.8, color='green')
ax.set_title('Status Bar Chart', fontsize=18)
ax.set_xlabel("Status", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
# plt.savefig('status_bar_chart')
# Out:
# Text(0, 0.5, 'Count')

# %%
#spotlight column is data leakage. Needs removal 
df[['state', 'spotlight']].groupby('spotlight').count()
# Out:
#            state
# spotlight
# False      82847
# True       97906

# %%
df[['state', 'staff_pick']].groupby('staff_pick').count()
# Out:
#              state
# staff_pick
# False       157840
# True         22913

# %%
# remove entries that are cancelled
df1 = df[df['state'].isin(['successful', 'failed', 'live'])]
df1.shape
# Out:
# (172160, 38)

# %%
cols_to_remove = ['friends', 'is_backing', 'is_starred', 'permissions', 
                   'currency_symbol', 'currency_trailing_code', 'spotlight',
                  'current_currency', 'currency','usd_type', 'source_url',
                  'country', 'disable_communication', 'fx_rate', 'photo',
                  'static_usd_rate', 'urls', 'created_at', 'is_starrable',
                 'location', 'profile', 'creator', 'id',
                 'usd_pledged', 'converted_pledged_amount', 'state_changed_at']
df2 = df1.drop(cols_to_remove, axis=1)
df2
# Out:
#         backers_count  \
# 0                   5
# 1                  19
# 2                   5
# 3                  23
# 4                   0
# ...               ...
# 338763             48
# 338764            179
# 338765             18
# 338766              0
# 338767              1
#
#                                                                                                       blurb  \
# 0       A Free to Win Online Mobile Strategy Game to end the corruption of the rich players always winni...
# 1                        Lizard is a dark comedy and modern western, that takes place in the Mojave Desert.
# 2       My friend and I are making an app that has never been made before. Making a football turn based ...
# 3                                                       More than a bike trip, a state of mind. And a book.
# 4       This is the birth of a revolutionary artist...Revery! A burst out into the world with GAME CHANG...
# ...                                                                                                     ...
# 338763              The bee all end all Kickstarter for crazy bitches. \nWe're raising funds for bee hives!
# 338764  Detective Tori Jones and her partner Officer Rashida Thompson are back!  Kicking crime's ass and...
# 338765                                       Help me produce the play I have written for my senior project!
# 338766  This documentary asks if the twenty-four hour news cycle has altered people's opinions of one an...
# 338767  a short film created by children ages 8-10. the premise of the movie is based on 3 kids who try ...
#
#                                                                                                    category  \
# 0       {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 1       {"id":11,"name":"Film & Video","slug":"film & video","position":7,"color":16734574,"urls":{"web"...
# 2       {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 3       {"id":48,"name":"Nonfiction","slug":"publishing/nonfiction","position":9,"parent_id":18,"parent_...
# 4       {"id":39,"name":"Hip-Hop","slug":"music/hip-hop","position":8,"parent_id":14,"parent_name":"Musi...
# ...                                                                                                     ...
# 338763  {"id":10,"name":"Food","slug":"food","position":8,"color":16725570,"urls":{"web":{"discover":"ht...
# 338764  {"id":33,"name":"Webseries","slug":"film & video/webseries","position":19,"parent_id":11,"parent...
# 338765  {"id":285,"name":"Plays","slug":"theater/plays","position":6,"parent_id":17,"parent_name":"Theat...
# 338766  {"id":21,"name":"Digital Art","slug":"art/digital art","position":3,"parent_id":1,"parent_name":...
# 338767  {"id":330,"name":"Family","slug":"film & video/family","position":7,"parent_id":11,"parent_name"...
#
#        country_displayable_name            deadline     goal  \
# 0                        Canada 2017-10-09 14:41:03   1000.0
# 1             the United States 2019-09-21 23:39:48   1100.0
# 2             the United States 2016-03-22 21:11:17  25000.0
# 3             the United States 2012-09-25 02:33:06    500.0
# 4             the United States 2017-12-11 02:43:11   2500.0
# ...                         ...                 ...      ...
# 338763        the United States 2019-03-29 22:35:40    550.0
# 338764        the United States 2012-05-19 04:00:00  30000.0
# 338765        the United States 2014-09-30 16:00:00    500.0
# 338766        the United States 2013-06-07 18:39:19  10000.0
# 338767        the United States 2014-08-06 21:04:08   3500.0
#
#                launched_at  \
# 0      2017-09-25 14:41:03
# 1      2019-07-23 23:39:48
# 2      2016-01-22 22:11:17
# 3      2012-09-15 02:33:06
# 4      2017-11-10 02:43:11
# ...                    ...
# 338763 2019-02-27 23:35:40
# 338764 2012-04-15 19:31:32
# 338765 2014-08-31 14:03:20
# 338766 2013-05-08 18:39:19
# 338767 2014-07-07 21:04:08
#
#                                                               name  pledged  \
# 0       Iron Age Kingdoms - First Free To Win Mobile Strategy Game    105.0
# 1                                            "Lizard" a short film   2358.0
# 2                                    Total Franchise Football 2016    172.0
# 3          The Trans-American Psychogeographic Literary Cycle Tour    501.0
# 4                           The Golden Ticket to the Wonka Factory      0.0
# ...                                                            ...      ...
# 338763                                     Bitches Bee Crazy Hives   2145.0
# 338764                          Lesbian Cops: The Movie - Season 2  30045.5
# 338765                                Generations (Senior Project)    606.0
# 338766                            US: A Story of our United States      0.0
# 338767                      Lights, Camera, and Behind the Action!     25.0
#
#                                                       slug  staff_pick  \
# 0       iron-age-kingdoms-first-free-to-win-mobile-strateg       False
# 1                                      lizard-a-short-film       False
# 2                            total-franchise-football-2016       False
# 3       the-trans-american-psychogeographic-literary-cycle       False
# 4                   the-golden-ticket-to-the-wonka-factory       False
# ...                                                    ...         ...
# 338763                             bitches-bee-crazy-hives       False
# 338764                   lesbian-cops-the-movie-season-2-0       False
# 338765                          generations-senior-project       False
# 338766                     us-a-story-of-our-united-states       False
# 338767                 lights-camera-and-behind-the-action       False
#
#              state
# 0           failed
# 1       successful
# 2           failed
# 3       successful
# 4           failed
# ...            ...
# 338763  successful
# 338764  successful
# 338765  successful
# 338766      failed
# 338767      failed
#
# [172160 rows x 12 columns]

# %%
print(df2.shape)
df2['state'].value_counts()
# Out:
# (172160, 12)
# successful    97906
# failed        71720
# live           2534
# Name: state, dtype: int64

# %%
df2['launched_year'] = df2['launched_at'].dt.year
df2['launched_month'] = df2['launched_at'].dt.month
df2['campaign_length'] = df2['deadline'] - df2['launched_at']
df2['campaign_length'] = df2['campaign_length'].dt.round('d').dt.days

# %%
df2
# Out:
#         backers_count  \
# 0                   5
# 1                  19
# 2                   5
# 3                  23
# 4                   0
# ...               ...
# 338763             48
# 338764            179
# 338765             18
# 338766              0
# 338767              1
#
#                                                                                                       blurb  \
# 0       A Free to Win Online Mobile Strategy Game to end the corruption of the rich players always winni...
# 1                        Lizard is a dark comedy and modern western, that takes place in the Mojave Desert.
# 2       My friend and I are making an app that has never been made before. Making a football turn based ...
# 3                                                       More than a bike trip, a state of mind. And a book.
# 4       This is the birth of a revolutionary artist...Revery! A burst out into the world with GAME CHANG...
# ...                                                                                                     ...
# 338763              The bee all end all Kickstarter for crazy bitches. \nWe're raising funds for bee hives!
# 338764  Detective Tori Jones and her partner Officer Rashida Thompson are back!  Kicking crime's ass and...
# 338765                                       Help me produce the play I have written for my senior project!
# 338766  This documentary asks if the twenty-four hour news cycle has altered people's opinions of one an...
# 338767  a short film created by children ages 8-10. the premise of the movie is based on 3 kids who try ...
#
#                                                                                                    category  \
# 0       {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 1       {"id":11,"name":"Film & Video","slug":"film & video","position":7,"color":16734574,"urls":{"web"...
# 2       {"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_...
# 3       {"id":48,"name":"Nonfiction","slug":"publishing/nonfiction","position":9,"parent_id":18,"parent_...
# 4       {"id":39,"name":"Hip-Hop","slug":"music/hip-hop","position":8,"parent_id":14,"parent_name":"Musi...
# ...                                                                                                     ...
# 338763  {"id":10,"name":"Food","slug":"food","position":8,"color":16725570,"urls":{"web":{"discover":"ht...
# 338764  {"id":33,"name":"Webseries","slug":"film & video/webseries","position":19,"parent_id":11,"parent...
# 338765  {"id":285,"name":"Plays","slug":"theater/plays","position":6,"parent_id":17,"parent_name":"Theat...
# 338766  {"id":21,"name":"Digital Art","slug":"art/digital art","position":3,"parent_id":1,"parent_name":...
# 338767  {"id":330,"name":"Family","slug":"film & video/family","position":7,"parent_id":11,"parent_name"...
#
#        country_displayable_name            deadline     goal  \
# 0                        Canada 2017-10-09 14:41:03   1000.0
# 1             the United States 2019-09-21 23:39:48   1100.0
# 2             the United States 2016-03-22 21:11:17  25000.0
# 3             the United States 2012-09-25 02:33:06    500.0
# 4             the United States 2017-12-11 02:43:11   2500.0
# ...                         ...                 ...      ...
# 338763        the United States 2019-03-29 22:35:40    550.0
# 338764        the United States 2012-05-19 04:00:00  30000.0
# 338765        the United States 2014-09-30 16:00:00    500.0
# 338766        the United States 2013-06-07 18:39:19  10000.0
# 338767        the United States 2014-08-06 21:04:08   3500.0
#
#                launched_at  \
# 0      2017-09-25 14:41:03
# 1      2019-07-23 23:39:48
# 2      2016-01-22 22:11:17
# 3      2012-09-15 02:33:06
# 4      2017-11-10 02:43:11
# ...                    ...
# 338763 2019-02-27 23:35:40
# 338764 2012-04-15 19:31:32
# 338765 2014-08-31 14:03:20
# 338766 2013-05-08 18:39:19
# 338767 2014-07-07 21:04:08
#
#                                                               name  pledged  \
# 0       Iron Age Kingdoms - First Free To Win Mobile Strategy Game    105.0
# 1                                            "Lizard" a short film   2358.0
# 2                                    Total Franchise Football 2016    172.0
# 3          The Trans-American Psychogeographic Literary Cycle Tour    501.0
# 4                           The Golden Ticket to the Wonka Factory      0.0
# ...                                                            ...      ...
# 338763                                     Bitches Bee Crazy Hives   2145.0
# 338764                          Lesbian Cops: The Movie - Season 2  30045.5
# 338765                                Generations (Senior Project)    606.0
# 338766                            US: A Story of our United States      0.0
# 338767                      Lights, Camera, and Behind the Action!     25.0
#
#                                                       slug  staff_pick  \
# 0       iron-age-kingdoms-first-free-to-win-mobile-strateg       False
# 1                                      lizard-a-short-film       False
# 2                            total-franchise-football-2016       False
# 3       the-trans-american-psychogeographic-literary-cycle       False
# 4                   the-golden-ticket-to-the-wonka-factory       False
# ...                                                    ...         ...
# 338763                             bitches-bee-crazy-hives       False
# 338764                   lesbian-cops-the-movie-season-2-0       False
# 338765                          generations-senior-project       False
# 338766                     us-a-story-of-our-united-states       False
# 338767                 lights-camera-and-behind-the-action       False
#
#              state  launched_year  launched_month  campaign_length
# 0           failed           2017               9               14
# 1       successful           2019               7               60
# 2           failed           2016               1               60
# 3       successful           2012               9               10
# 4           failed           2017              11               31
# ...            ...            ...             ...              ...
# 338763  successful           2019               2               30
# 338764  successful           2012               4               33
# 338765  successful           2014               8               30
# 338766      failed           2013               5               30
# 338767      failed           2014               7               30
#
# [172160 rows x 15 columns]

# %% [markdown]
# ## EDA

# %%
df2.describe()
# Out:
#        backers_count          goal       pledged  launched_year  \
# count  172160.000000  1.721600e+05  1.721600e+05  172160.000000
# mean      146.600674  5.144890e+04  2.174109e+04    2016.126208
# std       922.705482  1.208034e+06  7.633733e+05       2.271547
# min         0.000000  1.000000e-02  0.000000e+00    2009.000000
# 25%         4.000000  1.500000e+03  1.100000e+02    2015.000000
# 50%        27.000000  5.000000e+03  1.554000e+03    2016.000000
# 75%        90.000000  1.500000e+04  7.000000e+03    2018.000000
# max    105857.000000  1.000000e+08  2.353205e+08    2020.000000
#
#        launched_month  campaign_length
# count   172160.000000    172160.000000
# mean         6.321068        32.935792
# std          3.372272        12.109187
# min          1.000000         1.000000
# 25%          3.000000        30.000000
# 50%          6.000000        30.000000
# 75%          9.000000        35.000000
# max         12.000000        98.000000

# %%
max_days = df2.campaign_length.value_counts().index.max()
min_days = df2.campaign_length.value_counts().index.min()
print('The longest Kickstarter campaign length is: {}'.format(max_days))
print('The shortest Kickstarter campaign length is: {}'.format(min_days))
# Out:
# The longest Kickstarter campaign length is: 98
# The shortest Kickstarter campaign length is: 1

# %%
more_than_30 = df2[df2['campaign_length']>30].shape[0]
less_than_30 = df2[df2['campaign_length']<=30].shape[0]
print('There are {} Kickstarter projects with longer than 30 days length'.format(more_than_30))
print('There are {} Kickstarter projects with less than 30 days length'.format(less_than_30))
# Out:
# There are 57600 Kickstarter projects with longer than 30 days length
# There are 114560 Kickstarter projects with less than 30 days length

# %%
more_than_90 = df2[df2['campaign_length']>90].shape[0]
less_than_90 = df2[df2['campaign_length']<=90].shape[0]
print('There are {} Kickstarter projects with longer than 90 days length'.format(more_than_90))
print('There are {} Kickstarter projects with less than 90 days length'.format(less_than_90))
# Out:
# There are 35 Kickstarter projects with longer than 90 days length
# There are 172125 Kickstarter projects with less than 90 days length

# %%
# remove entries that are longer than 90 days in length
df2 = df2[df2['campaign_length']<=90]
df2.shape
# Out:
# (172125, 15)

# %%
df2['state'].value_counts()
# Out:
# successful    97880
# failed        71711
# live           2534
# Name: state, dtype: int64

# %%
df2['launched_year'].value_counts()
# Out:
# 2015    30521
# 2019    24933
# 2016    23821
# 2017    23117
# 2014    21288
# 2018    20549
# 2013     8684
# 2020     8135
# 2012     6418
# 2011     3305
# 2010     1166
# 2009      188
# Name: launched_year, dtype: int64

# %%
plt.figure(figsize=(16,6))
df.set_index('launched_at').category.resample('MS').count().plot()
plt.xlim('2009-01-01', '2020-05-01') # Limiting to whole months
plt.xlabel('Launch date', fontsize=16)
plt.ylabel('Number of projects', fontsize=16)
plt.title('Number of projects launched on Kickstarter, 2009-2020', fontsize=18)
plt.show()
# plt.savefig('monthly_recap')

# %%
#df1['country_displayable_name'].value_counts()
fig, ax = plt.subplots()

pie_data = df2['country_displayable_name'].value_counts()[:5]
colors = ['lightcoral', 'orange', 'green', 'lightskyblue', 'red']
explode = (0.05,0,0,0,0)
ax.pie(pie_data.values, explode=explode, labels=pie_data.index, 
       colors=colors, autopct='%1.1f%%', shadow=True)
ax.set_title('Distribution of Top 5 Countries')

plt.axis('equal')
plt.show()

# %%
df2['category'][0]
# Out:
# '{"id":272,"name":"Mobile Games","slug":"games/mobile games","position":3,"parent_id":12,"parent_name":"Games","color":51627,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/mobile%20games"}}}'

# %%
df2['category'][1]
# Out:
# '{"id":11,"name":"Film & Video","slug":"film & video","position":7,"color":16734574,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/film%20&%20video"}}}'

# %%
# To extract category type from category column
def extract(cat):
    x = ast.literal_eval(re.search('({.+})', cat).group(0))
    if 'parent_name' not in x.keys():
        return x['slug']
    else:
        return x['parent_name'].lower()

# %%
extract(df2['category'][1])
# Out:
# 'film & video'

# %%
df2['category_type'] = df2['category'].map(lambda x: extract(x))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2 = df2[df2['state'].isin(['successful', 'failed'])]

# %%
fig, ax = plt.subplots(figsize=(8,6))
x = df2.category_type.value_counts()
ax.bar(x.index, height=x.values)
ax.set_xticklabels(x.index, rotation=90)
ax.set_ylabel('Count')
ax.set_xlabel('Category Type')
ax.set_title('Category Type Count', size=16)
# Out:
# Text(0.5, 1.0, 'Category Type Count')

# %%
df2.category_type.value_counts()
# Out:
# film & video    25067
# music           21122
# technology      18524
# publishing      18022
# art             16811
# food            14216
# games           11075
# fashion          8666
# comics           6816
# design           6234
# crafts           5882
# theater          5141
# photography      4992
# journalism       3950
# dance            3073
# Name: category_type, dtype: int64

# %%
pledged_by_month = df2[['launched_month', 'state', 'pledged']].groupby(['launched_month', 'state']).mean()
pledged_by_month
# Out:
#                                 pledged
# launched_month state
# 1              failed       1476.448930
#                successful  31577.697567
# 2              failed       2157.471983
#                successful  55499.218732
# 3              failed       2012.464565
#                successful  39138.135382
# 4              failed       2122.505285
#                successful  24897.800510
# 5              failed       2241.477163
#                successful  33573.515058
# 6              failed       1630.195719
#                successful  36670.002050
# 7              failed       1474.726397
#                successful  28447.707852
# 8              failed       1359.479155
#                successful  26616.067393
# 9              failed       1400.694982
#                successful  35100.851661
# 10             failed       2981.827108
#                successful  49943.560606
# 11             failed       2102.879505
#                successful  31990.368814
# 12             failed       1405.164850
#                successful  35838.808749

# %%
total_pledged = df2[['category_type', 'state', 'pledged', 'backers_count']].groupby(['category_type']).sum()
total_pledged['avg'] = total_pledged['pledged']/total_pledged['backers_count']
total_pledged
# Out:
#                     pledged  backers_count         avg
# category_type
# art            9.690949e+07        1004471   96.478141
# comics         9.015795e+07        1357605   66.409558
# crafts         3.500879e+07         242521  144.353637
# dance          1.445048e+07         160403   90.088565
# design         5.157686e+08        2004470  257.309213
# fashion        1.523490e+08        1098838  138.645591
# film & video   4.107300e+08        2828913  145.190046
# food           1.133548e+08         932256  121.591913
# games          8.759638e+08        5496631  159.363769
# journalism     2.367019e+07         240949   98.237326
# music          1.423550e+08        1521355   93.571205
# photography    3.756104e+07         319097  117.710405
# publishing     1.555082e+08        2158082   72.058512
# technology     9.802297e+08        5153994  190.188367
# theater        2.727492e+07         265604  102.690152

# %%
a = sum(df2.pledged)
b = sum(df2.backers_count)
print(a/b)
# Out:
# 148.12443094019318

# %%
fig, ax = plt.subplots(figsize=(3,3))
df2.groupby('state').goal.median().plot(kind='bar', color = ['red', 'green'])
ax1.set_title('Median Pledge Goal')
# Out:
# Text(0.5, 1.0, 'Median Pledge Goal')

# %%
def word_count(blurb):
    count = 0
    if type(blurb) == str:
        count = len(blurb.split())
    else:
        count = 0
    return count

# %%
df2['blurb_length'] = df2['blurb'].map(lambda x: word_count(x))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['country_displayable_name'].value_counts().index[:10]
# Out:
# Index(['the United States', 'the United Kingdom', 'Canada', 'Australia',
#        'Germany', 'France', 'Mexico', 'Italy', 'Spain', 'the Netherlands'],
#       dtype='object')

# %%
df2['country_displayable_name'].value_counts()
# Out:
# the United States     120688
# the United Kingdom     19134
# Canada                  8007
# Australia               4034
# Germany                 3001
# France                  2375
# Mexico                  2277
# Italy                   2079
# Spain                   1807
# the Netherlands         1480
# Sweden                  1204
# Hong Kong               1014
# New Zealand              787
# Denmark                  747
# Singapore                618
# Switzerland              583
# Ireland                  549
# Belgium                  480
# Austria                  415
# Norway                   401
# Japan                    392
# Luxembourg                53
# Name: country_displayable_name, dtype: int64

# %%
def country_cat(x):
    country_list = ['the United States', 'the United Kingdom ', 'Canada', 'Australia',
                   'Germany', 'France', 'Mexico', 'Italy', 'Spain', 'the Netherlands']
    for country in x:
        if country in country_list:
            return country
        else:
            return 'other'

# %%
df2['country_name'] = df['country_displayable_name'].map(lambda x: country_cat([x]))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.shape
# Out:
# (172125, 18)

# %% [markdown]
# ## One Hot Encode!

# %%
# one hot encoding!!
df2_ohe = pd.get_dummies(df2[['category_type', 'country_name', 'staff_pick']])

# %%
df2.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'country_displayable_name',
#        'deadline', 'goal', 'launched_at', 'name', 'pledged', 'slug',
#        'staff_pick', 'state', 'launched_year', 'launched_month',
#        'campaign_length', 'category_type', 'blurb_length', 'country_name'],
#       dtype='object')

# %%
data = pd.merge(df2, df2_ohe, left_index=True, right_index=True)
data.shape
# Out:
# (172125, 44)

# %%
good_data = data[data['state'].isin(['successful', 'failed'])]
live = data[data['state'].isin(['live'])]
print(good_data.shape)
print(live.shape)
# Out:
# (169591, 44)
# (2534, 44)

# %%
good_data['state'] = good_data['state'].replace(to_replace=['successful', 'failed'], value=[1,0])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
model_data = good_data.copy()

# %%
model_data.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'country_displayable_name',
#        'deadline', 'goal', 'launched_at', 'name', 'pledged', 'slug',
#        'staff_pick_x', 'state', 'launched_year', 'launched_month',
#        'campaign_length', 'category_type', 'blurb_length', 'country_name',
#        'staff_pick_y', 'category_type_art', 'category_type_comics',
#        'category_type_crafts', 'category_type_dance', 'category_type_design',
#        'category_type_fashion', 'category_type_film & video',
#        'category_type_food', 'category_type_games', 'category_type_journalism',
#        'category_type_music', 'category_type_photography',
#        'category_type_publishing', 'category_type_technology',
#        'category_type_theater', 'country_name_Australia',
#        'country_name_Canada', 'country_name_France', 'country_name_Germany',
#        'country_name_Italy', 'country_name_Mexico', 'country_name_Spain',
#        'country_name_other', 'country_name_the Netherlands',
#        'country_name_the United States'],
#       dtype='object')

# %%
X = model_data.drop(['backers_count','blurb', 'category', 'country_displayable_name', 'deadline', 
                     'launched_at', 'name', 'staff_pick_y','pledged', 'slug', 'state', 'category_type', 'country_name'],
                   axis=1)
y = model_data['state']

# %%
X.shape
# Out:
# (169591, 31)

# %%
X = X*1

# %% [markdown]
# ## Modeling

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train
# Out:
#            goal  staff_pick_x  launched_year  launched_month  campaign_length  \
# 34051   20000.0             0           2014              11               60
# 310450   4500.0             1           2019               6               37
# 93359   17061.0             0           2017              11               30
# 336664   1000.0             0           2013              10               30
# 323583   2000.0             0           2017              12               21
# ...         ...           ...            ...             ...              ...
# 314590   6000.0             0           2017              12               30
# 283910   1500.0             0           2012              10               10
# 271905   1500.0             0           2017               4               55
# 310621    300.0             0           2016               5               21
# 120395   2500.0             0           2014               4               14
#
#         blurb_length  category_type_art  category_type_comics  \
# 34051             22                  0                     0
# 310450             6                  0                     0
# 93359             21                  0                     0
# 336664            18                  0                     0
# 323583            23                  0                     0
# ...              ...                ...                   ...
# 314590            21                  0                     0
# 283910            12                  0                     0
# 271905            11                  0                     0
# 310621            17                  0                     0
# 120395            14                  1                     0
#
#         category_type_crafts  category_type_dance  category_type_design  \
# 34051                      0                    0                     0
# 310450                     0                    0                     0
# 93359                      0                    0                     0
# 336664                     0                    1                     0
# 323583                     0                    0                     0
# ...                      ...                  ...                   ...
# 314590                     0                    0                     0
# 283910                     0                    0                     0
# 271905                     0                    0                     0
# 310621                     0                    0                     0
# 120395                     0                    0                     0
#
#         category_type_fashion  category_type_film & video  category_type_food  \
# 34051                       0                           1                   0
# 310450                      0                           0                   0
# 93359                       0                           0                   0
# 336664                      0                           0                   0
# 323583                      1                           0                   0
# ...                       ...                         ...                 ...
# 314590                      0                           0                   0
# 283910                      0                           0                   0
# 271905                      0                           0                   0
# 310621                      0                           0                   0
# 120395                      0                           0                   0
#
#         category_type_games  category_type_journalism  category_type_music  \
# 34051                     0                         0                    0
# 310450                    0                         0                    1
# 93359                     0                         0                    0
# 336664                    0                         0                    0
# 323583                    0                         0                    0
# ...                     ...                       ...                  ...
# 314590                    0                         0                    1
# 283910                    0                         0                    0
# 271905                    1                         0                    0
# 310621                    0                         0                    0
# 120395                    0                         0                    0
#
#         category_type_photography  category_type_publishing  \
# 34051                           0                         0
# 310450                          0                         0
# 93359                           0                         0
# 336664                          0                         0
# 323583                          0                         0
# ...                           ...                       ...
# 314590                          0                         0
# 283910                          0                         0
# 271905                          0                         0
# 310621                          0                         1
# 120395                          0                         0
#
#         category_type_technology  category_type_theater  \
# 34051                          0                      0
# 310450                         0                      0
# 93359                          1                      0
# 336664                         0                      0
# 323583                         0                      0
# ...                          ...                    ...
# 314590                         0                      0
# 283910                         1                      0
# 271905                         0                      0
# 310621                         0                      0
# 120395                         0                      0
#
#         country_name_Australia  country_name_Canada  country_name_France  \
# 34051                        1                    0                    0
# 310450                       0                    0                    1
# 93359                        0                    0                    0
# 336664                       0                    0                    0
# 323583                       0                    0                    0
# ...                        ...                  ...                  ...
# 314590                       0                    0                    0
# 283910                       0                    0                    0
# 271905                       0                    0                    0
# 310621                       0                    0                    0
# 120395                       0                    0                    0
#
#         country_name_Germany  country_name_Italy  country_name_Mexico  \
# 34051                      0                   0                    0
# 310450                     0                   0                    0
# 93359                      0                   0                    0
# 336664                     0                   0                    0
# 323583                     0                   0                    0
# ...                      ...                 ...                  ...
# 314590                     0                   0                    0
# 283910                     0                   0                    0
# 271905                     0                   0                    0
# 310621                     0                   0                    0
# 120395                     0                   0                    0
#
#         country_name_Spain  country_name_other  country_name_the Netherlands  \
# 34051                    0                   0                             0
# 310450                   0                   0                             0
# 93359                    1                   0                             0
# 336664                   0                   0                             0
# 323583                   0                   1                             0
# ...                    ...                 ...                           ...
# 314590                   0                   0                             0
# 283910                   0                   0                             0
# 271905                   0                   0                             0
# 310621                   0                   0                             0
# 120395                   0                   0                             0
#
#         country_name_the United States
# 34051                                0
# 310450                               0
# 93359                                0
# 336664                               1
# 323583                               0
# ...                                ...
# 314590                               1
# 283910                               1
# 271905                               1
# 310621                               1
# 120395                               1
#
# [127193 rows x 31 columns]

# %%
def get_scores(classifier, X_train, X_test, y_train, y_test, **kwargs):
    model = classifier(**kwargs)
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    return model.score(X_test, y_test), precision_score(y_test, y_predict), recall_score(y_test, y_predict)
print("Model, Accuracy, Precision, Recall")
print("    Random Forest:", get_scores(RandomForestClassifier, X_train, X_test, y_train, y_test))
print("    Logistic Regression:", get_scores(LogisticRegression, X_train, X_test, y_train, y_test))
print("    Gradient Boost:", get_scores(GradientBoostingClassifier, X_train, X_test, y_train, y_test))
# Out:
# Model, Accuracy, Precision, Recall
#     Random Forest: (0.7361196282843531, 0.7632259581471902, 0.7909999187718301)
#     Logistic Regression: (0.6253361007594698, 0.6235680140299268, 0.8953375030460564)
#     Gradient Boost: (0.7429831595829992, 0.7539127539127539, 0.8275525952400292)

# %%
lg = LogisticRegression()
lg.fit(X_train, y_train)
y_predict = lg.predict(X_test)
cv_score = cross_val_score(lg, X_train, y_train)
score = cross_val_score(lg, X_train, y_train, scoring = 'roc_auc')
tn, fp, fn, tp = confusion_matrix(y_test, y_predict).ravel()
print(np.array([[tp, fn], [fp, tn]]))
print('Cross val score: {}'.format(np.mean(cv_score)))
print('ROC_AUC score: {}'.format (np.mean(score)))
# Out:
# [[22045  2577]
#  [13308  4468]]
# Cross val score: 0.6258913443761188
# ROC_AUC score: 0.6332407403899889

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_predict = rf.predict(X_test)
cv_score = cross_val_score(rf, X_train, y_train)
score = cross_val_score(rf, X_train, y_train, scoring = 'roc_auc')
tn, fp, fn, tp = confusion_matrix(y_test, y_predict).ravel()
print(np.array([[tp, fn], [fp, tn]]))
print('Cross val score: {}'.format(np.mean(cv_score)))
print('ROC_AUC score: {}'.format (np.mean(score)))
# Out:
# [[19262  5195]
#  [ 6201 11740]]
# Cross val score: 0.7344822526312935
# ROC_AUC score: 0.806285568961699

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_predict = gb.predict(X_test)
cv_score = cross_val_score(gb, X_train, y_train)
score = cross_val_score(gb, X_train, y_train, scoring = 'roc_auc')
tn, fp, fn, tp = confusion_matrix(y_test, y_predict).ravel()
print(np.array([[tp, fn], [fp, tn]]))
print('Cross val score: {}'.format(np.mean(cv_score)))
print('ROC_AUC score: {}'.format (np.mean(score)))
# Out:
# [[20156  4301]
#  [ 7018 10923]]
# Cross val score: 0.7404416700464507
# ROC_AUC score: 0.8135814632388488

# %%
rf_feature_importances = np.argsort(gb.feature_importances_)
print("Top five:", list(X.columns[rf_feature_importances][-1:-11:-1]))
# Out:
# Top five: ['goal', 'staff_pick_x', 'launched_year', 'campaign_length', 'category_type_food', 'category_type_technology', 'category_type_design', 'category_type_journalism', 'category_type_crafts', 'category_type_art']

# %%
lg = LogisticRegression()
lg.fit(X,y)
importance = lg.coef_[0]

# for idx, elem in enumerate(importance):
#     print('Feature: %0d, Score: %0.5f' % (idx, elem))
    
lg_feature_importance = np.argsort(importance)
print("Top five:", list(X.columns[lg_feature_importance][-1:-11:-1]))
# Out:
# Top five: ['staff_pick_x', 'launched_year', 'category_type_publishing', 'category_type_comics', 'category_type_music', 'country_name_the United States', 'category_type_games', 'category_type_fashion', 'country_name_other', 'category_type_dance']

# %%
n = 10 # top 10 features

lg_importances = lg.coef_[0][:n]

indices = np.argsort(lg_importances)[::-1]
features = list(X.columns[indices])

# Print the feature ranking
print("Feature ranking:")

for f in range(n):
    print("%d. %s (%f)" % (f + 1, features[f], lg_importances[indices[f]]))

# Plot the feature importances
fig, ax = plt.subplots()

ax.bar(range(10), lg_importances[indices], color='lightcoral', align="center")
ax.set_xticks(range(10))
ax.set_xticklabels(features, rotation = 90, fontsize=12)
ax.set_xlim([-1, 10])
ax.set_xlabel("Importance", fontsize=16)
ax.set_title("Feature Importances for Logistic Regression", fontsize=16)
# Out:
# Feature ranking:
# 1. staff_pick_x (0.001336)
# 2. launched_year (0.000683)
# 3. category_type_comics (0.000306)
# 4. category_type_dance (0.000105)
# 5. category_type_art (0.000028)
# 6. goal (-0.000004)
# 7. category_type_crafts (-0.000190)
# 8. launched_month (-0.000942)
# 9. blurb_length (-0.003655)
# 10. campaign_length (-0.027660)
# Text(0.5, 1.0, 'Feature Importances for Logistic Regression')

# %%
n = 10 # top 10 features


importances = gb.feature_importances_[:n]

indices = np.argsort(importances)[::-1]
features = list(X.columns[indices])

# Print the feature ranking
print("Feature ranking:")

for f in range(n):
    print("%d. %s (%f)" % (f + 1, features[f], importances[indices[f]]))

# Plot the feature importances
fig, ax = plt.subplots()

ax.bar(range(10), importances[indices], color='lightcoral', align="center")
ax.set_xticks(range(10))
ax.set_xticklabels(features, rotation = 90, fontsize=12)
ax.set_xlim([-1, 10])
ax.set_xlabel("Importance", fontsize=16)
ax.set_title("Feature Importances for Gradient Boost Classifier", fontsize=16)
# Out:
# Feature ranking:
# 1. goal (0.291412)
# 2. launched_year (0.165930)
# 3. staff_pick_y (0.125546)
# 4. staff_pick_x (0.116686)
# 5. campaign_length (0.099623)
# 6. category_type_crafts (0.018910)
# 7. category_type_art (0.012902)
# 8. category_type_comics (0.010053)
# 9. blurb_length (0.007473)
# 10. launched_month (0.000188)
# Text(0.5, 1.0, 'Feature Importances for Gradient Boost Classifier')

# %% [markdown]
# ## Neural Network

# %%
n_samples, n_feats = X_train.shape

tf_model = Sequential() 

denselayer = Dense(units=1,
                input_dim=n_feats,
                kernel_initializer='uniform',
                activation='sigmoid')
hidden_layer = Dense(units=200,
                kernel_initializer='uniform',
                activation='relu')
hidden_layer1 = Dense(units=100,
                kernel_initializer='uniform',
                activation='sigmoid')
out_layer = Dense(units=1,
                 kernel_initializer='uniform',
                activation='sigmoid')
tf_model.add(denselayer)
tf_model.add(hidden_layer)
tf_model.add(hidden_layer1)
tf_model.add(out_layer)
tf_model.compile(loss='binary_crossentropy', optimizer='adam', 
                 metrics=[Accuracy()])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Train on 127193 samples
# Epoch 1/10
# 127193/127193 [==============================] - 15s 122us/sample - loss: 33.6918 - accuracy: 0.2489
# Epoch 2/10
# 127193/127193 [==============================] - 15s 121us/sample - loss: 21.3995 - accuracy: 0.1912
# Epoch 3/10
# 127193/127193 [==============================] - 17s 133us/sample - loss: 24.0078 - accuracy: 0.1960
# Epoch 4/10
# 127193/127193 [==============================] - 18s 139us/sample - loss: 17.8051 - accuracy: 0.2009
# Epoch 5/10
# 127193/127193 [==============================] - 18s 138us/sample - loss: 38.3142 - accuracy: 0.2630
# Epoch 6/10
# 127193/127193 [==============================] - 18s 143us/sample - loss: 24.2508 - accuracy: 0.1995
# Epoch 7/10
# 127193/127193 [==============================] - 18s 141us/sample - loss: 23.2316 - accuracy: 0.2118
# Epoch 8/10
# 127193/127193 [==============================] - 18s 142us/sample - loss: 31.4619 - accuracy: 0.2044
# Epoch 9/10
# 127193/127193 [==============================] - 19s 151us/sample - loss: 24.9912 - accuracy: 0.2036
# Epoch 10/10
# 127193/127193 [==============================] - 25s 194us/sample - loss: 30.1951 - accuracy: 0.2397

# %%
n_samples, n_feats = X_train.shape

model = Sequential() # sequence of layers

denselayer = Dense(units=1,
                input_dim=n_feats,
                kernel_initializer='uniform',
                activation='sigmoid')

model.add(denselayer)
model.compile(loss='binary_crossentropy', optimizer='adam', 
                 metrics=[Accuracy()])

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Train on 127193 samples
# Epoch 1/20
# 127193/127193 [==============================] - 24s 186us/sample - loss: 32.5718 - accuracy: 0.1868
# Epoch 2/20
# 127193/127193 [==============================] - 26s 206us/sample - loss: 34.1207 - accuracy: 0.1768
# Epoch 3/20
# 127193/127193 [==============================] - 28s 217us/sample - loss: 35.6821 - accuracy: 0.1969
# Epoch 4/20
# 127193/127193 [==============================] - 25s 200us/sample - loss: 13.9899 - accuracy: 0.1027
# Epoch 5/20
# 127193/127193 [==============================] - 25s 193us/sample - loss: 37.8606 - accuracy: 0.2211
# Epoch 6/20
# 127193/127193 [==============================] - 24s 188us/sample - loss: 38.9339 - accuracy: 0.2881
# Epoch 7/20
# 127193/127193 [==============================] - 24s 191us/sample - loss: 24.9688 - accuracy: 0.2213
# Epoch 8/20
# 127193/127193 [==============================] - 25s 194us/sample - loss: 44.2456 - accuracy: 0.3001
# Epoch 9/20
# 127193/127193 [==============================] - 26s 206us/sample - loss: 34.9283 - accuracy: 0.2163
# Epoch 10/20
# 127193/127193 [==============================] - 24s 190us/sample - loss: 19.9765 - accuracy: 0.1934
# Epoch 11/20
# 127193/127193 [==============================] - 25s 197us/sample - loss: 26.4955 - accuracy: 0.2260
# Epoch 12/20
# 127193/127193 [==============================] - 23s 179us/sample - loss: 41.0121 - accuracy: 0.2712
# Epoch 13/20
# 127193/127193 [==============================] - 23s 178us/sample - loss: 29.5323 - accuracy: 0.2643
# Epoch 14/20
# 127193/127193 [==============================] - 23s 181us/sample - loss: 25.6145 - accuracy: 0.1943
# Epoch 15/20
# 127193/127193 [==============================] - 24s 191us/sample - loss: 26.2651 - accuracy: 0.2065
# Epoch 16/20
# 127193/127193 [==============================] - 23s 181us/sample - loss: 7.9128 - accuracy: 0.1580
# Epoch 17/20
# 127193/127193 [==============================] - 25s 200us/sample - loss: 18.4265 - accuracy: 0.1990
# Epoch 18/20
# 127193/127193 [==============================] - 25s 199us/sample - loss: 37.2528 - accuracy: 0.2338
# Epoch 19/20
# 127193/127193 [==============================] - 23s 180us/sample - loss: 29.9580 - accuracy: 0.2286
# Epoch 20/20
# 127193/127193 [==============================] - 23s 181us/sample - loss: 26.8920 - accuracy: 0.2263

# %% [markdown]
# ## NLP

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# drop two rows of blurb with Nan, and Japanese
df_nlp = df2.drop(axis=0, index=[14, 55244])

# %%
vader_analyzer = SentimentIntensityAnalyzer()

def vader_neg(words):
    d = vader_analyzer.polarity_scores(words)
    return d['neg']
def vader_neu(words):
    d = vader_analyzer.polarity_scores(words)
    return d['neu']
def vader_pos(words):
    d = vader_analyzer.polarity_scores(words)
    return d['pos']
def vader_com(words):
    d = vader_analyzer.polarity_scores(words)
    return d['compound']

df_nlp['blurb_neg'] = df_nlp['blurb'].map(lambda x: vader_neg(x))
df_nlp['blurb_neu'] = df_nlp['blurb'].map(lambda x: vader_neu(x))
df_nlp['blurb_pos'] = df_nlp['blurb'].map(lambda x: vader_pos(x))
df_nlp['blurb_compound'] = df_nlp['blurb'].map(lambda x: vader_com(x))

# %%
df_nlp.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'country_displayable_name',
#        'deadline', 'goal', 'launched_at', 'name', 'pledged', 'slug',
#        'staff_pick', 'state', 'launched_year', 'launched_month',
#        'campaign_length', 'category_type', 'blurb_length', 'country_name',
#        'blurb_neg', 'blurb_neu', 'blurb_pos', 'blurb_compound'],
#       dtype='object')

# %%
model_data.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'country_displayable_name',
#        'deadline', 'goal', 'launched_at', 'name', 'pledged', 'slug',
#        'staff_pick_x', 'state', 'launched_year', 'launched_month',
#        'campaign_length', 'category_type', 'blurb_length', 'country_name',
#        'staff_pick_y', 'category_type_art', 'category_type_comics',
#        'category_type_crafts', 'category_type_dance', 'category_type_design',
#        'category_type_fashion', 'category_type_film & video',
#        'category_type_food', 'category_type_games', 'category_type_journalism',
#        'category_type_music', 'category_type_photography',
#        'category_type_publishing', 'category_type_technology',
#        'category_type_theater', 'country_name_Australia',
#        'country_name_Canada', 'country_name_France', 'country_name_Germany',
#        'country_name_Italy', 'country_name_Mexico', 'country_name_Spain',
#        'country_name_other', 'country_name_the Netherlands',
#        'country_name_the United States', 'name_length'],
#       dtype='object')

# %%
# merging nlp tables with model table
df_nlp_extract = df_nlp.loc[:, 'blurb_neg': 'blurb_compound']
model_data_nlp = pd.merge(model_data, df_nlp_extract, left_index=True, right_index=True)

# %%
model_data_nlp.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'country_displayable_name',
#        'deadline', 'goal', 'launched_at', 'name', 'pledged', 'slug',
#        'staff_pick_x', 'state', 'launched_year', 'launched_month',
#        'campaign_length', 'category_type', 'blurb_length', 'country_name',
#        'staff_pick_y', 'category_type_art', 'category_type_comics',
#        'category_type_crafts', 'category_type_dance', 'category_type_design',
#        'category_type_fashion', 'category_type_film & video',
#        'category_type_food', 'category_type_games', 'category_type_journalism',
#        'category_type_music', 'category_type_photography',
#        'category_type_publishing', 'category_type_technology',
#        'category_type_theater', 'country_name_Australia',
#        'country_name_Canada', 'country_name_France', 'country_name_Germany',
#        'country_name_Italy', 'country_name_Mexico', 'country_name_Spain',
#        'country_name_other', 'country_name_the Netherlands',
#        'country_name_the United States', 'name_length', 'blurb_neg',
#        'blurb_neu', 'blurb_pos', 'blurb_compound'],
#       dtype='object')

# %%
X = model_data_nlp.drop(['backers_count','blurb', 'category', 'country_displayable_name', 'deadline', 
                     'launched_at', 'name', 'pledged', 'slug', 'state', 'category_type', 'country_name', 'name_length',
                    ],
                   axis=1)
y = model_data_nlp['state']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
def get_scores(classifier, X_train, X_test, y_train, y_test, **kwargs):
    model = classifier(**kwargs)
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    return model.score(X_test, y_test), precision_score(y_test, y_predict), recall_score(y_test, y_predict)
print("Model, Accuracy, Precision, Recall")
print("    Random Forest:", get_scores(RandomForestClassifier, X_train, X_test, y_train, y_test))
print("    Logistic Regression:", get_scores(LogisticRegression, X_train, X_test, y_train, y_test))
print("    Gradient Boost:", get_scores(GradientBoostingClassifier, X_train, X_test, y_train, y_test))
# Out:
# Model, Accuracy, Precision, Recall
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#     Random Forest: (0.718689560828341, 0.772984953753037, 0.733141979301423)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     Logistic Regression: (0.6221991603377518, 0.6104718941659486, 0.9738033635187581)
#     Gradient Boost: (0.7424406811642058, 0.7559087204563977, 0.8249110608020699)

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_predict = gb.predict(X_test)
cv_score = cross_val_score(gb, X_train, y_train)
score = cross_val_score(gb, X_train, y_train, scoring = 'roc_auc')
tn, fp, fn, tp = confusion_matrix(y_test, y_predict).ravel()
print(np.array([[tp, fn], [fp, tn]]))
print('Cross val score: {}'.format(np.mean(cv_score)))
print('ROC_AUC score: {}'.format (np.mean(score)))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [[20405  4331]
#  [ 6589 11073]]
# Cross val score: 0.7386450120162378
# ROC_AUC score: 0.8125653700448027
